# %% [markdown]
# # Analyzing Portfolio Risk and Return
#
# In this Challenge, you'll assume the role of a quantitative analyst for a FinTech investing platform. This platform aims to offer clients a one-stop online investment solution for their retirement portfolios that’s both inexpensive and high quality. (Think about [Wealthfront](https://www.wealthfront.com/) or [Betterment](https://www.betterment.com/)). To keep the costs low, the firm uses algorithms to build each client's portfolio. The algorithms choose from various investment styles and options.
#
# You've been tasked with evaluating four new investment options for inclusion in the client portfolios. Legendary fund and hedge-fund managers run all four selections. (People sometimes refer to these managers as **whales**, because of the large amount of money that they manage). You’ll need to determine the fund with the most investment potential based on key risk-management metrics: the daily returns, standard deviations, Sharpe ratios, and betas.
#
# ## Instructions
#
# ### ✔️Import the Data
#
# Use the `whale_analysis.ipynb` file to complete the following steps:
#
# 1. ✔️Import the required libraries and dependencies.
#
# 2. ✔️Use the `read_csv` function and the `Path` module to read the `whale_navs.csv` file into a Pandas DataFrame. Be sure to create a `DateTimeIndex`. Review the first five rows of the DataFrame by using the `head` function.
#
# 3. ✔️Use the Pandas `pct_change` function together with `dropna` to create the daily returns DataFrame. Base this DataFrame on the NAV prices of the four portfolios and on the closing price of the S&P 500 Index. Review the first five rows of the daily returns DataFrame.
#
# ### ✔️Analyze the Performance
#
# Analyze the data to determine if any of the portfolios outperform the broader stock market, which the S&P 500 represents. To do so, complete the following steps:
#
# 1. ✔️Use the default Pandas `plot` function to visualize the daily return data of the four fund portfolios and the S&P 500. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. ✔️Use the Pandas `cumprod` function to calculate the cumulative returns for the four fund portfolios and the S&P 500. Review the last five rows of the cumulative returns DataFrame by using the Pandas `tail` function.
#
# 3. ✔️Use the default Pandas `plot` to visualize the cumulative return values for the four funds and the S&P 500 over time. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. ✔️Answer the following question: Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?
#
# ### ✔️Analyze the Volatility
#
# Analyze the volatility of each of the four fund portfolios and of the S&P 500 Index by using box plots. To do so, complete the following steps:
#
# 1. ✔️Use the Pandas `plot` function and the `kind="box"` parameter to visualize the daily return data for each of the four portfolios and for the S&P 500 in a box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 2. ✔️Use the Pandas `drop` function to create a new DataFrame that contains the data for just the four fund portfolios by dropping the S&P 500 column. Visualize the daily return data for just the four fund portfolios by using another box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
#     > **Hint** Save this new DataFrame&mdash;the one that contains the data for just the four fund portfolios. You’ll use it throughout the analysis.
#
# 3. ✔️Answer the following question: Based on the box plot visualization of just the four fund portfolios, which fund was the most volatile (with the greatest spread) and which was the least volatile (with the smallest spread)?
#
# ### ✔️Analyze the Risk
#
# Evaluate the risk profile of each portfolio by using the standard deviation and the beta. To do so, complete the following steps:
#
# 1. ✔️Use the Pandas `std` function to calculate the standard deviation for each of the four portfolios and for the S&P 500. Review the standard deviation calculations, sorted from smallest to largest.
#
# 2. ✔️Calculate the annualized standard deviation for each of the four portfolios and for the S&P 500. To do that, multiply the standard deviation by the square root of the number of trading days. Use 252 for that number.
#
# 3. ✔️Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of the four fund portfolios and of the S&P 500 index. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. ✔️Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of only the four fund portfolios. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 5. ✔️Answer the following three questions:
#
# * ✔️Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# * ✔️Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# * ✔️Based on the rolling standard deviations of only the four fund portfolios, which portfolio poses the most risk? Does this change over time?
#
# ### ✔️Analyze the Risk-Return Profile
#
# To determine the overall risk of an asset or portfolio, quantitative analysts and investment managers consider not only its risk metrics but also its risk-return profile. After all, if you have two portfolios that each offer a 10% return but one has less risk, you’d probably invest in the smaller-risk portfolio. For this reason, you need to consider the Sharpe ratios for each portfolio. To do so, complete the following steps:
#
# 1. ✔️Use the daily return DataFrame to calculate the annualized average return data for the four fund portfolios and for the S&P 500. Use 252 for the number of trading days. Review the annualized average returns, sorted from lowest to highest.
#
# 2. ✔️Calculate the Sharpe ratios for the four fund portfolios and for the S&P 500. To do that, divide the annualized average return by the annualized standard deviation for each. Review the resulting Sharpe ratios, sorted from lowest to highest.
#
# 3. ✔️Visualize the Sharpe ratios for the four funds and for the S&P 500 in a bar chart. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# 4. ✔️Answer the following question: Which of the four portfolios offers the best risk-return profile? Which offers the worst?
#
# #### Diversify the Portfolio
#
# ✔️Your analysis is nearing completion. Now, you need to evaluate how the portfolios react relative to the broader market. Based on your analysis so far, choose two portfolios that you’re most likely to recommend as investment options. To start your analysis, complete the following step:
#
# * ✔️Use the Pandas `var` function to calculate the variance of the S&P 500 by using a 60-day rolling window. Visualize the last five rows of the variance of the S&P 500.
#
# ✔️Next, for each of the two portfolios that you chose, complete the following steps:
#
# 1. ✔️✔️Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.
#
# 2. ✔️✔️Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.
#
# 3. ✔️✔️Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.
#
# 4. ✔️✔️Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.
#
# Finally, answer the following two questions:
#
# * ✔️Which of the two portfolios seem more sensitive to movements in the S&P 500?
#
# * ✔️Which of the two portfolios do you recommend for inclusion in your firm’s suite of fund offerings?

# %% [markdown]
# ### Import the Data

# %% [markdown]
# #### Step 1: Import the required libraries and dependencies.

# %%
# Import the required libraries and dependencies
import pandas as pd         # extensive utilization of the DataFrame structure and included financial metric calculation functions
import numpy as np          # used to calculate square roots
from pathlib import Path    # used to verify and format links to other resources
# %matplotlib inline          # invoke rendering of matplotlib plots inline with code/markdown inside the jupyter notebook
# Out:
# UsageError: unrecognized arguments: # invoke rendering of matplotlib plots inline with code/markdown inside the jupyter notebook

# %% [markdown]
# #### Step 2: Use the `read_csv` function and the `Path` module to read the `whale_navs.csv` file into a Pandas DataFrame. Be sure to create a `DateTimeIndex`. Review the first five rows of the DataFrame by using the `head` function.

# %%
# Import the data by reading in the CSV file and setting the DatetimeIndex 
whale_nav_df = pd.read_csv(
    Path('./Resources/whale_navs.csv'),
    index_col='date',
    parse_dates=True,
    infer_datetime_format=True
)

# Review the first 5 rows of the DataFrame
display(whale_nav_df.head())
display(whale_nav_df.tail())
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# date
# 2014-10-01                  31.950240          14.991826
# 2014-10-02                  31.936110          14.994072
# 2014-10-03                  31.969707          14.999596
# 2014-10-06                  32.048215          14.999471
# 2014-10-07                  31.964216          14.994720
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC  S&P 500
# date
# 2014-10-01                    59.977830               51.948712   194.35
# 2014-10-02                    59.978626               51.957619   194.38
# 2014-10-03                    60.002264               52.022484   196.52
# 2014-10-06                    60.006244               52.036387   196.29
# 2014-10-07                    59.993735               52.005864   193.26
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# date
# 2020-09-04                  31.546221          14.364969
# ...

# %% [markdown]
# ##### Step 2b: change the column names to something actually practical to call. Also, create a list of names for later when plotting.

# %%
'''
    Thought about using this to make it easier to invoke the individual fund series from the dataframe,
    but elected ultimately to forego it since my couple attempts at altering label names within plots
    didn't immediately prove successful ergo decided it wasn't worth it for sake of time.

# create a blank list to add the full firm's names to
full_column_names = []

# loop through the column names of the dataframe and append each name to the list
for name in whale_nav_df.columns:
    full_column_names.append(name)

# create a new list of column names that are more easily codeable
short_column_names = ['soros','pnc','tiglo','berk','snp']
'''
# Out:
# "\n    Thought about using this to make it easier to invoke the individual fund series from the dataframe,\n    but elected ultimately to forego it since my couple attempts at altering label names within plots\n    didn't immediately prove successful ergo decided it wasn't worth it for sake of time.\n\n# create a blank list to add the full firm's names to\nfull_column_names = []\n\n# loop through the column names of the dataframe and append each name to the list\nfor name in whale_nav_df.columns:\n    full_column_names.append(name)\n\n# create a new list of column names that are more easily codeable\nshort_column_names = ['soros','pnc','tiglo','berk','snp']\n"

# %% [markdown]
# #### Step 3: Use the Pandas `pct_change` function together with `dropna` to create the daily returns DataFrame. Base this DataFrame on the NAV prices of the four portfolios and on the closing price of the S&P 500 Index. Review the first five rows of the daily returns DataFrame.

# %%
# Prepare for the analysis by converting the dataframe of NAVs and prices to daily ~percentage~ returns; drop all NaN values.
nav_daily_returns = whale_nav_df.pct_change().dropna()
# Review the first five rows of the daily returns DataFrame.
nav_daily_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# date
# 2014-10-02                  -0.000442           0.000150
# 2014-10-03                   0.001052           0.000368
# 2014-10-06                   0.002456          -0.000008
# 2014-10-07                  -0.002621          -0.000317
# 2014-10-08                   0.000390           0.000369
# ...                               ...                ...
# 2020-09-04                  -0.001079           0.005050
# 2020-09-08                  -0.001737          -0.001888
# 2020-09-09                   0.001115           0.002123
# 2020-09-10                  -0.001258           0.001389
# 2020-09-11                  -0.000418          -0.001930
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC   S&P 500
# date
# 2014-10-02                     0.000013                0.000171  0.000154
# 2014-10-03                     0.000394                0.001248  0.011009
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Quantative Analysis
#
# The analysis has several components: performance, volatility, risk, risk-return profile, and portfolio diversification. You’ll analyze each component one at a time.

# %% [markdown]
# ###  Analyze the Performance
#
# Analyze the data to determine if any of the portfolios outperform the broader stock market, which the S&P 500 represents.

# %% [markdown]
# #### Step 1:  Use the default Pandas `plot` function to visualize the daily return data of the four fund portfolios and the S&P 500. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
'''
    This has to do with the previous docstring wanting to rename columns and make life easier when isolating each fund from the dataframe,
    but didn't end up being worth the time right now. Maintiaining a record of it because I appreciated an elegant simplicity in:
            "temp_list_of_names.insert(0, temp_list_of_names.pop(temp_list_of_names.index('name_to_move_to_front')))"
    
    ~~~ found here: https://stackoverflow.com/questions/25122099/move-column-by-name-to-front-of-table-in-pandas ~~~ by user Sachinmm
    

# Step 1a: move the S&P 500 column to the front because it's getting in the way of everything else
swap_column_names = nav_daily_returns.columns.tolist()
# take the 'snp' column from wherever it is in the 'swap_column_names' temporary list, and put it in the first position in the list
swap_column_names.insert(0, swap_column_names.pop(swap_column_names.index('S&P 500')))
# actually reindex the 'nav_daily_returns' dataframe to reflect the order change found in 'swap_column_names'
nav_daily_returns = nav_daily_returns.reindex(columns=swap_column_names)
'''

# Plot the daily return data of the 4 funds and the S&P 500 
# Inclue a title parameter and adjust the figure size
nav_daily_returns.plot(figsize=(20,10),title='Daily Returns')
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='date'>

# %% [markdown]
# #### Step 2: Use the Pandas `cumprod` function to calculate the cumulative returns for the four fund portfolios and the S&P 500. Review the last five rows of the cumulative returns DataFrame by using the Pandas `tail` function.

# %%
# Calculate and plot the cumulative returns of the 4 fund portfolios and the S&P 500
nav_cumulative_returns = (1 + nav_daily_returns).cumprod()
# Review the last 5 rows of the cumulative returns DataFrame
nav_cumulative_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# date
# 2020-09-04                   0.987355           0.958187
# 2020-09-08                   0.985640           0.956378
# 2020-09-09                   0.986739           0.958409
# 2020-09-10                   0.985498           0.959740
# 2020-09-11                   0.985086           0.957887
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC   S&P 500
# date
# 2020-09-04                     1.055714                1.244856  1.762645
# 2020-09-08                     1.054373                1.238608  1.714484
# 2020-09-09                     1.057221                1.240858  1.748341
# 2020-09-10                     1.055539                1.237883  1.717983
# 2020-09-11                     1.055081                1.236625  1.718858

# %% [markdown]
# #### Step 3: Use the default Pandas `plot` to visualize the cumulative return values for the four funds and the S&P 500 over time. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Visualize the cumulative returns using the Pandas plot function
nav_cumulative_returns.plot(figsize=(35,20),title='Cumulative Returns')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='date'>

# %% [markdown]
# #### Step 4: Answer the following question: Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?

# %% [markdown]
# **Question** Based on the cumulative return data and the visualization, do any of the four fund portfolios outperform the S&P 500 Index?
#
# **Answer**
#
# Only for a small handful of short periods all prior to the second-half of 2016 does the S&P 500 <u>***not***</u> outperform the other four funds.

# %% [markdown]
# ---

# %% [markdown]
# ### Analyze the Volatility
#
# Analyze the volatility of each of the four fund portfolios and of the S&P 500 Index by using box plots.

# %% [markdown]
# #### Step 1: Use the Pandas `plot` function and the `kind="box"` parameter to visualize the daily return data for each of the four portfolios and for the S&P 500 in a box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Use the daily return data to create box plots to visualize the volatility of the 4 funds and the S&P 500 
# Include a title parameter and adjust the figure size
nav_daily_returns.plot(kind='box',figsize=(15,8),title='Box Plot -- Volatility')
# Out:
# <AxesSubplot:title={'center':'Box Plot -- Volatility'}>

# %% [markdown]
# #### Step 2: Use the Pandas `drop` function to create a new DataFrame that contains the data for just the four fund portfolios by dropping the S&P 500 column. Visualize the daily return data for just the four fund portfolios by using another box plot. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Create a new DataFrame containing only the 4 fund portfolios by dropping the S&P 500 column from the DataFrame
# Create box plots to reflect the return data for only the 4 fund portfolios
# Include a title parameter and adjust the figure size
nav_daily_returns_only_funds = nav_daily_returns.drop(columns='S&P 500')
nav_daily_returns_only_funds.plot(kind='box',figsize=(15,8),title='Box Plot -- Fund Volatility')
# Out:
# <AxesSubplot:title={'center':'Box Plot -- Fund Volatility'}>

# %% [markdown]
# #### Step 3: Answer the following question: Based on the box plot visualization of just the four fund portfolios, which fund was the most volatile (with the greatest spread) and which was the least volatile (with the smallest spread)?

# %% [markdown]
# **Question** Based on the box plot visualization of just the four fund portfolios, which fund was the most volatile (with the greatest spread) and which was the least volatile (with the smallest spread)?
#
# **Answer**
#
# Based on the box plot visualization, Berkshire Hathaway was the most volatile, and Tiget Global Management was the least volatile.

# %% [markdown]
# ---

# %% [markdown]
# ### Analyze the Risk
#
# Evaluate the risk profile of each portfolio by using the standard deviation and the beta.

# %% [markdown]
# #### Step 1: Use the Pandas `std` function to calculate the standard deviation for each of the four portfolios and for the S&P 500. Review the standard deviation calculations, sorted from smallest to largest.

# %%
# Calculate and sort the standard deviation for all 4 portfolios and the S&P 500
# Review the standard deviations sorted smallest to largest
nav_daily_returns_std = nav_daily_returns.std()
nav_daily_returns_std.sort_values()
# Out:
# TIGER GLOBAL MANAGEMENT LLC    0.000996
# SOROS FUND MANAGEMENT LLC      0.001405
# PAULSON & CO.INC.              0.002199
# BERKSHIRE HATHAWAY INC         0.003256
# S&P 500                        0.011550
# dtype: float64

# %% [markdown]
# #### Step 2: Calculate the annualized standard deviation for each of the four portfolios and for the S&P 500. To do that, multiply the standard deviation by the square root of the number of trading days. Use 252 for that number.

# %%
# Calculate and sort the annualized standard deviation (252 trading days) of the 4 portfolios and the S&P 500
# Review the annual standard deviations smallest to largest
nav_daily_returns_annualized_std = nav_daily_returns_std * np.sqrt(252)
nav_daily_returns_annualized_std.sort_values()
# Out:
# TIGER GLOBAL MANAGEMENT LLC    0.015804
# SOROS FUND MANAGEMENT LLC      0.022297
# PAULSON & CO.INC.              0.034912
# BERKSHIRE HATHAWAY INC         0.051692
# S&P 500                        0.183345
# dtype: float64

# %% [markdown]
# #### Step 3: Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of the four fund portfolios and of the S&P 500 index. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Using the daily returns DataFrame and a 21-day rolling window, 
# plot the rolling standard deviation of the 4 portfolios and the S&P 500
# Include a title parameter and adjust the figure size
nav_daily_returns.rolling(window=21).std().plot(figsize=(25,10),title='21-Day Rolling Standard Deviation')
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling Standard Deviation'}, xlabel='date'>

# %% [markdown]
# #### Step 4: Use the daily returns DataFrame and a 21-day rolling window to plot the rolling standard deviations of only the four fund portfolios. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Using the daily return data and a 21-day rolling window, plot the rolling standard deviation of just the 4 portfolios. 
# Include a title parameter and adjust the figure size
nav_daily_returns_only_funds.rolling(window=21).std().plot(figsize=(25,10),title='21-Day Rolling Standard Deviation')
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling Standard Deviation'}, xlabel='date'>

# %% [markdown]
# #### Step 5: Answer the following three questions:
#
# 1. Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# 2. Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# 3. Based on the rolling standard deviations of only the four fund portfolios, which portfolio poses the most risk? Does this change over time?

# %% [markdown]
# **Question 1**  Based on the annualized standard deviation, which portfolios pose more risk than the S&P 500?
#
# **Answer 1**
#
# Based on the annualized standard deviation, <u>***none***</u> of the portfolios pose more risk than the S&P 500.

# %% [markdown]
# **Question 2** Based on the rolling metrics, does the risk of each portfolio increase at the same time that the risk of the S&P 500 increases?
#
# **Answer 2**
#
# Based on the rolling metrics, while many movements by the S&P 500 are partially mimic'd by other funds no definitive correlation exists to indicate the risk of each portfolio will increase in tandem with the risk of the S&P 500.

# %% [markdown]
# **Question 3** Based on the rolling standard deviations of only the four fund portfolios, which portfolio poses the most risk? Does this change over time?
#
# **Answer 3**
#
# Based on the rolling standard deviations of only the four fund portfolios, Berkshire Hathaway generally carries with it the most risk; however, this is not hold true throughout the entire dataset. For example, Berkshire first takes the lead in terms of risk beginning in the second half of 2016 and lasting into the first quarter of 2019. After which point, Paulson & Co begins competing for the riskiest portfolio, and the two trade-off for that title through the end of the dataset.

# %% [markdown]
# ---

# %% [markdown]
# ### Analyze the Risk-Return Profile
#
# To determine the overall risk of an asset or portfolio, quantitative analysts and investment managers consider not only its risk metrics but also its risk-return profile. After all, if you have two portfolios that each offer a 10% return but one has less risk, you’d probably invest in the smaller-risk portfolio. For this reason, you need to consider the Sharpe ratios for each portfolio.

# %% [markdown]
# #### Step 1: Use the daily return DataFrame to calculate the annualized average return data for the four fund portfolios and for the S&P 500. Use 252 for the number of trading days. Review the annualized average returns, sorted from lowest to highest.

# %%
# Calculate the annual average return data for the for fund portfolios and the S&P 500
# Use 252 as the number of trading days in the year
# Review the annual average returns sorted from lowest to highest
nav_average_annual_returns = nav_daily_returns.mean() * 252
nav_average_annual_returns.sort_values()
# Out:
# PAULSON & CO.INC.             -0.006633
# SOROS FUND MANAGEMENT LLC     -0.002281
# TIGER GLOBAL MANAGEMENT LLC    0.009151
# BERKSHIRE HATHAWAY INC         0.037090
# S&P 500                        0.108102
# dtype: float64

# %% [markdown]
# #### Step 2: Calculate the Sharpe ratios for the four fund portfolios and for the S&P 500. To do that, divide the annualized average return by the annualized standard deviation for each. Review the resulting Sharpe ratios, sorted from lowest to highest.

# %%
# Calculate the annualized Sharpe Ratios for each of the 4 portfolios and the S&P 500.
# Review the Sharpe ratios sorted lowest to highest
nav_sharpe_ratio = nav_average_annual_returns / nav_daily_returns_annualized_std
nav_sharpe_ratio_sorted = nav_sharpe_ratio.sort_values()
nav_sharpe_ratio_sorted
# Out:
# PAULSON & CO.INC.             -0.189998
# SOROS FUND MANAGEMENT LLC     -0.102290
# TIGER GLOBAL MANAGEMENT LLC    0.579002
# S&P 500                        0.589612
# BERKSHIRE HATHAWAY INC         0.717512
# dtype: float64

# %% [markdown]
# #### Step 3: Visualize the Sharpe ratios for the four funds and for the S&P 500 in a bar chart. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Visualize the Sharpe ratios as a bar chart
# Include a title parameter and adjust the figure size
nav_sharpe_ratio.plot.bar(figsize=(10,5),title='Sharpe Ratio Bar Plot')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio Bar Plot'}>

# %% [markdown]
# #### Step 4: Answer the following question: Which of the four portfolios offers the best risk-return profile? Which offers the worst?

# %% [markdown]
# **Question** Which of the four portfolios offers the best risk-return profile? Which offers the worst?
#
# **Answer**
#
# **Berkshire Hathaway** offers the *best* risk-return profile while **Paulson & Co** offers the *worst* risk-return profile.

# %% [markdown]
# ---

# %% [markdown]
# ### Diversify the Portfolio
#
# Your analysis is nearing completion. Now, you need to evaluate how the portfolios react relative to the broader market. Based on your analysis so far, choose two portfolios that you’re most likely to recommend as investment options.

# %% [markdown]
# #### Use the Pandas `var` function to calculate the variance of the S&P 500 by using a 60-day rolling window. Visualize the last five rows of the variance of the S&P 500.

# %%
# Calculate the variance of the S&P 500 using a rolling 60-day window.
snp_rolling_60_variance = nav_daily_returns['S&P 500'].rolling(window=60).var().dropna()
snp_rolling_60_variance.tail()
# Out:
# date
# 2020-09-04    0.000103
# 2020-09-08    0.000116
# 2020-09-09    0.000120
# 2020-09-10    0.000121
# 2020-09-11    0.000120
# Name: S&P 500, dtype: float64

# %% [markdown]
# #### For each of the two portfolios that you chose, complete the following steps:
#
# 1. Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.
#
# 2. Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.
#
# 3. Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.
#
# 4. Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %% [markdown]
# ##### Portfolio 1 - Step 1: Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.

# %%
# Calculate the covariance using a 60-day rolling window 
# Review the last five rows of the covariance data
berk_rolling_60_covariance = nav_daily_returns['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(nav_daily_returns['S&P 500'].rolling(window=60))
berk_rolling_60_covariance.tail()
# Out:
# date
# 2020-09-04    0.000021
# 2020-09-08    0.000023
# 2020-09-09    0.000024
# 2020-09-10    0.000024
# 2020-09-11    0.000024
# dtype: float64

# %% [markdown]
# ##### Portfolio 1 - Step 2: Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.

# %%
# Calculate the beta based on the 60-day rolling covariance compared to the market (S&P 500)
berk_rolling_60_beta = berk_rolling_60_covariance / snp_rolling_60_variance
berk_rolling_60_beta.dropna(inplace=True)
berk_rolling_60_beta
# Out:
# date
# 2014-12-26    0.046920
# 2014-12-29    0.046960
# 2014-12-30    0.045166
# 2014-12-31    0.045679
# 2015-01-02    0.046140
#                 ...
# 2020-09-04    0.207879
# 2020-09-08    0.203051
# 2020-09-09    0.196632
# 2020-09-10    0.197543
# 2020-09-11    0.199411
# Length: 1438, dtype: float64

# %% [markdown]
# ##### Portfolio 1 - Step 3: Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.

# %%
# Calculate the average of the 60-day rolling beta
berk_average_rolling_60_beta = berk_rolling_60_beta.mean()
berk_average_rolling_60_beta
# Out:
# 0.2214986101354593

# %% [markdown]
# ##### Portfolio 1 - Step 4: Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Plot the rolling beta 
# Include a title parameter and adjust the figure size
berk_rolling_60_beta.plot(figsize=(15,8),title='60-Day Rolling Beta -- Berkshire Hathaway')
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta -- Berkshire Hathaway'}, xlabel='date'>

# %% [markdown]
# ##### Portfolio 2 - Step 1: Using the 60-day rolling window, the daily return data, and the S&P 500 returns, calculate the covariance. Review the last five rows of the covariance of the portfolio.

# %%
# Calculate the covariance using a 60-day rolling window 
# Review the last five rows of the covariance data
tiglo_rolling_60_covariance = nav_daily_returns['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=60).cov(nav_daily_returns['S&P 500'].rolling(window=60))
tiglo_rolling_60_covariance.tail()
# Out:
# date
# 2020-09-04    0.000008
# 2020-09-08    0.000009
# 2020-09-09    0.000010
# 2020-09-10    0.000010
# 2020-09-11    0.000010
# dtype: float64

# %% [markdown]
# ##### Portfolio 2 - Step 2: Calculate the beta of the portfolio. To do that, divide the covariance of the portfolio by the variance of the S&P 500.

# %%
# Calculate the beta based on the 60-day rolling covariance compared to the market (S&P 500)
# Review the last five rows of the beta information
tiglo_rolling_60_beta = tiglo_rolling_60_covariance / snp_rolling_60_variance
tiglo_rolling_60_beta.dropna(inplace=True)
tiglo_rolling_60_beta
# Out:
# date
# 2014-12-26    0.017361
# 2014-12-29    0.017362
# 2014-12-30    0.016998
# 2014-12-31    0.017557
# 2015-01-02    0.017759
#                 ...
# 2020-09-04    0.081061
# 2020-09-08    0.076672
# 2020-09-09    0.079575
# 2020-09-10    0.080934
# 2020-09-11    0.081378
# Length: 1438, dtype: float64

# %% [markdown]
# ##### Portfolio 2 - Step 3: Use the Pandas `mean` function to calculate the average value of the 60-day rolling beta of the portfolio.

# %%
# Calculate the average of the 60-day rolling beta
tiglo_average_rolling_60_beta = tiglo_rolling_60_beta.mean()
tiglo_average_rolling_60_beta
# Out:
# 0.03093001487238774

# %% [markdown]
# ##### Portfolio 2 - Step 4: Plot the 60-day rolling beta. Be sure to include the `title` parameter, and adjust the figure size if necessary.

# %%
# Plot the rolling beta 
# Include a title parameter and adjust the figure size
tiglo_rolling_60_beta.plot(figsize=(15,8),title='60-Day Rolling Beta -- Tiger Global Management')
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta -- Tiger Global Management'}, xlabel='date'>

# %% [markdown]
# #### Answer the following two questions:
#
# 1. Which of the two portfolios seem more sensitive to movements in the S&P 500?
#
# 2. Which of the two portfolios do you recommend for inclusion in your firm’s suite of fund offerings?

# %% [markdown]
# **Question 1** Which of the two portfolios seem more sensitive to movements in the S&P 500?
#
# **Answer 1**
#
# Berkshire Hathaway appears to be more sensitive to movements in the S&P 500. This is corroborated by the 60-day average rolling beta calculation of both Berkshire Hathaway as well as Tiger Global Management;
#
# Berkshire's ***0.2215*** indicates a level of higher sensitivity to the S&P in comparison to Tiger's ***0.0309***.

# %% [markdown]
# **Question 2** Which of the two portfolios do you recommend for inclusion in your firm’s suite of fund offerings?
#
# **Answer 2**
#
# Depending on the goal of the particular investor, even though Berkshire Hathaway's sensitivity to market fluctuations is higher than Tiger Global Management's, *as shown by the average 60-day rolling beta*, Berkshire Hathaway's higher *Sharpe Ratio* in comparison to Tiger Global Management's indicates for the given risk profile ***Berkshire Hathaway*** is the correct recommendation for our firm's suite of fund offerings.
#
# If the investor desires a fund enabling capitalization on overall market movement while mitigating market volatility, then the Berkshire Hathaway fund provides the most attractive offering in comparison to the list of other funds in question.

# %% [markdown]
# ---
